# %%
#Sth to do with association rules
#look at how things are laid out
#cross-selling, up-selling, ....

#Simple example in Association Rules
#https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules

# %%
#pip install mlxtend
#A simple example to demonstrate Association Rules using the mlxtend library
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

#create a sample dataset
#each row represents a shopping basket with items purchased
dataset = [
    ['Milk', 'Bread', 'Eggs'],
    ['Bread', 'Diapers', 'Beer', 'Eggs'],
    ['Milk', 'Diapers', 'Bread', 'Cola'],
    ['Bread', 'Milk', 'Diapers', 'Beer'],
    ['Milk', 'Bread','Eggs'],
    ['Bread', 'Diapers', 'Cola']
]

#convert the dataset into a one-hot encoded Dataframe
#Each item gets its own column with True/False values indicating presence/absence in the basket
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_data = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_data, columns=te.columns_)

print("One-hot encoded DataFrame:")
print(df)
print("\n")
#find frequent itemsets using the Apriori algorithm
#min_support=0.6 means the itemset must appear in at least 60% of the transactions
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
print("Frequent Itemsets:")
print(frequent_itemsets) #Wasnt there in the original code in class
print("\n")

#Generate association rules from the frequent itemsets
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# One-hot encoded DataFrame:
#     Beer  Bread   Cola  Diapers   Eggs   Milk
# 0  False   True  False    False   True   True
# 1   True   True  False     True   True  False
# 2  False   True   True     True  False   True
# 3   True   True  False     True  False   True
# 4  False   True  False    False   True   True
# 5  False   True   True     True  False  False
#
#
# Frequent Itemsets:
#     support          itemsets
# 0  1.000000           (Bread)
# 1  0.666667         (Diapers)
# 2  0.666667            (Milk)
# 3  0.666667  (Diapers, Bread)
# 4  0.666667     (Bread, Milk)
#
#
# Association Rules:
#   antecedents consequents   support  confidence  lift
# 0   (Diapers)     (Bread)  0.666667         1.0   1.0
# 1      (Milk)     (Bread)  0.666667         1.0   1.0
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
# ...

# %% [markdown]
# Push to github using git
# notion of maximality
# notion of closedness
#
# Prepare a readme a detailed one for todays class and push it.
# Finish up on the group assignment
